# %% [markdown]
# # Business Problem

# %% [markdown]
# A lot of people visit NYC for various reasons. NYC is a hub for bankers, IT professionals, tourists etc. It is multi cultural with people from all over the world residing/visiting it. It also has variety of cuisines to satisfy the taste buds of its multi ethnic groups. NYC is divided into 5 Borough namely: Bronx, Manhattan, Brooklyn, Queens and Staten Island. If a tourist who is a big pizza lover wants to visit New York City, he/she would love to reside in that Borough from where the pizza places are easily accessible.
#
# This research will benefit all the pizza lovers who will be travelling to New York. This will help them choose the Borough to stay which will give access to Pizza Places options with ease.

# %% [markdown]
# # Data Section

# %% [markdown]
# I will use New york data to find out the city where we have maximum Pizza places

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0
import folium # map rendering library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

neighborhoods_data = newyork_data['features']

# Dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

neighborhoods = pd.DataFrame(columns=column_names)

# %%
for record in neighborhoods_data:
    borough = neighborhood_name = record['properties']['borough'] 
    neighborhood_name = record['properties']['name']
        
    neighborhood_latlon = record['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
neighborhoods
# Out:
#            Borough               Neighborhood   Latitude  Longitude
# 0            Bronx                  Wakefield  40.894705 -73.847201
# 1            Bronx                 Co-op City  40.874294 -73.829939
# 2            Bronx                Eastchester  40.887556 -73.827806
# 3            Bronx                  Fieldston  40.895437 -73.905643
# 4            Bronx                  Riverdale  40.890834 -73.912585
# 5            Bronx                Kingsbridge  40.881687 -73.902818
# 6        Manhattan                Marble Hill  40.876551 -73.910660
# 7            Bronx                   Woodlawn  40.898273 -73.867315
# 8            Bronx                    Norwood  40.877224 -73.879391
# 9            Bronx             Williamsbridge  40.881039 -73.857446
# 10           Bronx                 Baychester  40.866858 -73.835798
# 11           Bronx             Pelham Parkway  40.857413 -73.854756
# 12           Bronx                City Island  40.847247 -73.786488
# 13           Bronx               Bedford Park  40.870185 -73.885512
# 14           Bronx         University Heights  40.855727 -73.910416
# 15           Bronx             Morris Heights  40.847898 -73.919672
# 16           Bronx                    Fordham  40.860997 -73.896427
# 17           Bronx               East Tremont  40.842696 -73.887356
# 18           Bronx                 West Farms  40.839475 -73.877745
# 19           Bronx               High  Bridge  40.836623 -73.926102
# 20           Bronx                    Melrose  40.819754 -73.909422
# 21           Bronx                 Mott Haven  40.806239 -73.916100
# 22           Bronx                Port Morris  40.801664 -73.913221
# 23           Bronx                   Longwood  40.815099 -73.895788
# 24           Bronx                Hunts Point  40.809730 -73.883315
# 25           Bronx                 Morrisania  40.823592 -73.901506
# 26           Bronx                  Soundview  40.821012 -73.865746
# 27           Bronx               Clason Point  40.806551 -73.854144
# 28           Bronx                Throgs Neck  40.815109 -73.816350
# 29           Bronx               Country Club  40.844246 -73.824099
# 30           Bronx                Parkchester  40.837938 -73.856003
# 31           Bronx         Westchester Square  40.840619 -73.842194
# 32           Bronx                   Van Nest  40.843608 -73.866299
# 33           Bronx                Morris Park  40.847549 -73.850402
# 34           Bronx                    Belmont  40.857277 -73.888452
# 35           Bronx             Spuyten Duyvil  40.881395 -73.917190
# 36           Bronx            North Riverdale  40.908543 -73.904531
# 37           Bronx                 Pelham Bay  40.850641 -73.832074
# 38           Bronx              Schuylerville  40.826580 -73.826203
# 39           Bronx             Edgewater Park  40.821986 -73.813885
# 40           Bronx                Castle Hill  40.819014 -73.848027
# 41           Bronx                  Olinville  40.871371 -73.863324
# 42           Bronx             Pelham Gardens  40.862966 -73.841612
# 43           Bronx                  Concourse  40.834284 -73.915589
# 44           Bronx                  Unionport  40.829774 -73.850535
# 45           Bronx                   Edenwald  40.884561 -73.848083
# 46        Brooklyn                  Bay Ridge  40.625801 -74.030621
# 47        Brooklyn                Bensonhurst  40.611009 -73.995180
# 48        Brooklyn                Sunset Park  40.645103 -74.010316
# 49        Brooklyn                 Greenpoint  40.730201 -73.954241
# 50        Brooklyn                  Gravesend  40.595260 -73.973471
# 51        Brooklyn             Brighton Beach  40.576825 -73.965094
# 52        Brooklyn             Sheepshead Bay  40.586890 -73.943186
# 53        Brooklyn          Manhattan Terrace  40.614433 -73.957438
# 54        Brooklyn                   Flatbush  40.636326 -73.958401
# 55        Brooklyn              Crown Heights  40.670829 -73.943291
# 56        Brooklyn              East Flatbush  40.641718 -73.936103
# 57        Brooklyn                 Kensington  40.642382 -73.980421
# 58        Brooklyn            Windsor Terrace  40.656946 -73.980073
# 59        Brooklyn           Prospect Heights  40.676822 -73.964859
# 60        Brooklyn                Brownsville  40.663950 -73.910235
# 61        Brooklyn               Williamsburg  40.707144 -73.958115
# 62        Brooklyn                   Bushwick  40.698116 -73.925258
# 63        Brooklyn         Bedford Stuyvesant  40.687232 -73.941785
# 64        Brooklyn           Brooklyn Heights  40.695864 -73.993782
# 65        Brooklyn                Cobble Hill  40.687920 -73.998561
# 66        Brooklyn            Carroll Gardens  40.680540 -73.994654
# 67        Brooklyn                   Red Hook  40.676253 -74.012759
# 68        Brooklyn                    Gowanus  40.673931 -73.994441
# 69        Brooklyn                Fort Greene  40.688527 -73.972906
# 70        Brooklyn                 Park Slope  40.672321 -73.977050
# 71        Brooklyn              Cypress Hills  40.682391 -73.876616
# 72        Brooklyn              East New York  40.669926 -73.880699
# 73        Brooklyn              Starrett City  40.647589 -73.879370
# 74        Brooklyn                   Canarsie  40.635564 -73.902093
# 75        Brooklyn                  Flatlands  40.630446 -73.929113
# 76        Brooklyn                Mill Island  40.606336 -73.908186
# 77        Brooklyn            Manhattan Beach  40.577914 -73.943537
# 78        Brooklyn               Coney Island  40.574293 -73.988683
# 79        Brooklyn                 Bath Beach  40.599519 -73.998752
# 80        Brooklyn               Borough Park  40.633131 -73.990498
# 81        Brooklyn              Dyker Heights  40.619219 -74.019314
# 82        Brooklyn            Gerritsen Beach  40.590848 -73.930102
# 83        Brooklyn                Marine Park  40.609748 -73.931344
# 84        Brooklyn               Clinton Hill  40.693229 -73.967843
# 85        Brooklyn                   Sea Gate  40.576375 -74.007873
# 86        Brooklyn                   Downtown  40.690844 -73.983463
# 87        Brooklyn                Boerum Hill  40.685683 -73.983748
# 88        Brooklyn  Prospect Lefferts Gardens  40.658420 -73.954899
# 89        Brooklyn                 Ocean Hill  40.678403 -73.913068
# 90        Brooklyn                  City Line  40.678570 -73.867976
# 91        Brooklyn               Bergen Beach  40.615150 -73.898556
# 92        Brooklyn                    Midwood  40.625596 -73.957595
# 93        Brooklyn        Prospect Park South  40.647009 -73.962613
# 94        Brooklyn                 Georgetown  40.623845 -73.916075
# 95        Brooklyn          East Williamsburg  40.708492 -73.938858
# 96        Brooklyn                 North Side  40.714823 -73.958809
# 97        Brooklyn                 South Side  40.710861 -73.958001
# 98        Brooklyn              Ocean Parkway  40.613060 -73.968367
# 99        Brooklyn              Fort Hamilton  40.614768 -74.031979
# 100      Manhattan                  Chinatown  40.715618 -73.994279
# 101      Manhattan         Washington Heights  40.851903 -73.936900
# 102      Manhattan                     Inwood  40.867684 -73.921210
# 103      Manhattan           Hamilton Heights  40.823604 -73.949688
# 104      Manhattan             Manhattanville  40.816934 -73.957385
# 105      Manhattan             Central Harlem  40.815976 -73.943211
# 106      Manhattan                East Harlem  40.792249 -73.944182
# 107      Manhattan            Upper East Side  40.775639 -73.960508
# 108      Manhattan                  Yorkville  40.775930 -73.947118
# 109      Manhattan                 Lenox Hill  40.768113 -73.958860
# 110      Manhattan           Roosevelt Island  40.762160 -73.949168
# 111      Manhattan            Upper West Side  40.787658 -73.977059
# 112      Manhattan             Lincoln Square  40.773529 -73.985338
# 113      Manhattan                    Clinton  40.759101 -73.996119
# 114      Manhattan                    Midtown  40.754691 -73.981669
# 115      Manhattan                Murray Hill  40.748303 -73.978332
# 116      Manhattan                    Chelsea  40.744035 -74.003116
# 117      Manhattan          Greenwich Village  40.726933 -73.999914
# 118      Manhattan               East Village  40.727847 -73.982226
# 119      Manhattan            Lower East Side  40.717807 -73.980890
# 120      Manhattan                    Tribeca  40.721522 -74.010683
# 121      Manhattan               Little Italy  40.719324 -73.997305
# 122      Manhattan                       Soho  40.722184 -74.000657
# 123      Manhattan               West Village  40.734434 -74.006180
# 124      Manhattan           Manhattan Valley  40.797307 -73.964286
# 125      Manhattan        Morningside Heights  40.808000 -73.963896
# 126      Manhattan                   Gramercy  40.737210 -73.981376
# 127      Manhattan          Battery Park City  40.711932 -74.016869
# 128      Manhattan         Financial District  40.707107 -74.010665
# 129         Queens                    Astoria  40.768509 -73.915654
# 130         Queens                   Woodside  40.746349 -73.901842
# 131         Queens            Jackson Heights  40.751981 -73.882821
# 132         Queens                   Elmhurst  40.744049 -73.881656
# 133         Queens               Howard Beach  40.654225 -73.838138
# 134         Queens                     Corona  40.742382 -73.856825
# 135         Queens               Forest Hills  40.725264 -73.844475
# 136         Queens                Kew Gardens  40.705179 -73.829819
# 137         Queens              Richmond Hill  40.697947 -73.831833
# 138         Queens                   Flushing  40.764454 -73.831773
# 139         Queens           Long Island City  40.750217 -73.939202
# 140         Queens                  Sunnyside  40.740176 -73.926916
# 141         Queens              East Elmhurst  40.764073 -73.867041
# 142         Queens                    Maspeth  40.725427 -73.896217
# 143         Queens                  Ridgewood  40.708323 -73.901435
# 144         Queens                   Glendale  40.702762 -73.870742
# 145         Queens                  Rego Park  40.728974 -73.857827
# 146         Queens                  Woodhaven  40.689887 -73.858110
# 147         Queens                 Ozone Park  40.680708 -73.843203
# 148         Queens           South Ozone Park  40.668550 -73.809865
# 149         Queens              College Point  40.784903 -73.843045
# 150         Queens                 Whitestone  40.781291 -73.814202
# 151         Queens                    Bayside  40.766041 -73.774274
# 152         Queens                 Auburndale  40.761730 -73.791762
# 153         Queens                Little Neck  40.770826 -73.738898
# 154         Queens                 Douglaston  40.766846 -73.742498
# 155         Queens                  Glen Oaks  40.749441 -73.715481
# 156         Queens                  Bellerose  40.728573 -73.720128
# 157         Queens          Kew Gardens Hills  40.722578 -73.820878
# 158         Queens              Fresh Meadows  40.734394 -73.782713
# 159         Queens                  Briarwood  40.710935 -73.811748
# 160         Queens             Jamaica Center  40.704657 -73.796902
# 161         Queens            Oakland Gardens  40.745619 -73.754950
# 162         Queens             Queens Village  40.718893 -73.738715
# 163         Queens                     Hollis  40.711243 -73.759250
# 164         Queens              South Jamaica  40.696911 -73.790426
# 165         Queens                 St. Albans  40.694445 -73.758676
# 166         Queens                   Rochdale  40.675211 -73.772588
# 167         Queens        Springfield Gardens  40.666230 -73.760421
# 168         Queens            Cambria Heights  40.692775 -73.735269
# 169         Queens                   Rosedale  40.659816 -73.735261
# 170         Queens               Far Rockaway  40.603134 -73.754980
# 171         Queens              Broad Channel  40.603027 -73.820055
# 172         Queens               Breezy Point  40.557401 -73.925512
# 173         Queens                   Steinway  40.775923 -73.902290
# 174         Queens                 Beechhurst  40.792781 -73.804365
# 175         Queens                Bay Terrace  40.782843 -73.776802
# 176         Queens                   Edgemere  40.595642 -73.776133
# 177         Queens                    Arverne  40.589144 -73.791992
# 178         Queens             Rockaway Beach  40.582802 -73.822361
# 179         Queens                   Neponsit  40.572037 -73.857547
# 180         Queens                Murray Hill  40.764126 -73.812763
# 181         Queens                Floral Park  40.741378 -73.708847
# 182         Queens                 Holliswood  40.720957 -73.767142
# 183         Queens            Jamaica Estates  40.716805 -73.787227
# 184         Queens            Queensboro Hill  40.744572 -73.825809
# 185         Queens                  Hillcrest  40.723825 -73.797603
# 186         Queens                 Ravenswood  40.761705 -73.931575
# 187         Queens                 Lindenwood  40.663918 -73.849638
# 188         Queens                  Laurelton  40.667884 -73.740256
# 189         Queens                Lefrak City  40.736075 -73.862525
# 190         Queens               Belle Harbor  40.576156 -73.854018
# 191         Queens              Rockaway Park  40.580343 -73.841534
# 192         Queens                 Somerville  40.597711 -73.796648
# 193         Queens                 Brookville  40.660003 -73.751753
# 194         Queens                   Bellaire  40.733014 -73.738892
# 195         Queens               North Corona  40.754071 -73.857518
# 196         Queens       Forest Hills Gardens  40.714611 -73.841022
# 197  Staten Island                 St. George  40.644982 -74.079353
# 198  Staten Island               New Brighton  40.640615 -74.087017
# 199  Staten Island                  Stapleton  40.626928 -74.077902
# 200  Staten Island                   Rosebank  40.615305 -74.069805
# 201  Staten Island              West Brighton  40.631879 -74.107182
# 202  Staten Island                Grymes Hill  40.624185 -74.087248
# 203  Staten Island                  Todt Hill  40.597069 -74.111329
# 204  Staten Island                South Beach  40.580247 -74.079553
# 205  Staten Island              Port Richmond  40.633669 -74.129434
# 206  Staten Island           Mariner's Harbor  40.632546 -74.150085
# 207  Staten Island                 Port Ivory  40.639683 -74.174645
# 208  Staten Island          Castleton Corners  40.613336 -74.119181
# 209  Staten Island            New Springville  40.594252 -74.164960
# 210  Staten Island                     Travis  40.586314 -74.190737
# 211  Staten Island                   New Dorp  40.572572 -74.116479
# 212  Staten Island                    Oakwood  40.558462 -74.121566
# 213  Staten Island                Great Kills  40.549480 -74.149324
# 214  Staten Island                Eltingville  40.542231 -74.164331
# 215  Staten Island                   Annadale  40.538114 -74.178549
# 216  Staten Island                    Woodrow  40.541968 -74.205246
# 217  Staten Island                Tottenville  40.505334 -74.246569
# 218  Staten Island              Tompkinsville  40.637316 -74.080554
# 219  Staten Island                Silver Lake  40.619193 -74.096290
# 220  Staten Island                  Sunnyside  40.612760 -74.097126
# 221       Brooklyn                Ditmas Park  40.643675 -73.961013
# 222       Brooklyn                    Wingate  40.660947 -73.937187
# 223       Brooklyn                      Rugby  40.655572 -73.926882
# 224  Staten Island                  Park Hill  40.609190 -74.080157
# 225  Staten Island                Westerleigh  40.621090 -74.133041
# 226  Staten Island               Graniteville  40.620172 -74.153152
# 227  Staten Island                  Arlington  40.635325 -74.165104
# 228  Staten Island                   Arrochar  40.596313 -74.067124
# 229  Staten Island                   Grasmere  40.598268 -74.076674
# 230  Staten Island                   Old Town  40.596329 -74.087511
# 231  Staten Island               Dongan Hills  40.588673 -74.096399
# 232  Staten Island              Midland Beach  40.573527 -74.093483
# 233  Staten Island                 Grant City  40.576216 -74.105856
# 234  Staten Island             New Dorp Beach  40.564255 -74.104327
# 235  Staten Island                Bay Terrace  40.553988 -74.139166
# 236  Staten Island                   Huguenot  40.531912 -74.191741
# 237  Staten Island            Pleasant Plains  40.524699 -74.219831
# 238  Staten Island               Butler Manor  40.506082 -74.229504
# 239  Staten Island                 Charleston  40.530531 -74.232158
# 240  Staten Island                  Rossville  40.549404 -74.215729
# 241  Staten Island              Arden Heights  40.549286 -74.185887
# 242  Staten Island                 Greenridge  40.555295 -74.170794
# 243  Staten Island          Heartland Village  40.589139 -74.159022
# 244  Staten Island                    Chelsea  40.594726 -74.189560
# 245  Staten Island                 Bloomfield  40.605779 -74.187256
# 246  Staten Island                 Bulls Head  40.609592 -74.159409
# 247      Manhattan              Carnegie Hill  40.782683 -73.953256
# 248      Manhattan                       Noho  40.723259 -73.988434
# 249      Manhattan               Civic Center  40.715229 -74.005415
# 250      Manhattan              Midtown South  40.748510 -73.988713
# 251  Staten Island              Richmond Town  40.569606 -74.134057
# 252  Staten Island                Shore Acres  40.609719 -74.066678
# 253  Staten Island                    Clifton  40.619178 -74.072642
# 254  Staten Island                    Concord  40.604473 -74.084024
# 255  Staten Island               Emerson Hill  40.606794 -74.097762
# 256  Staten Island              Randall Manor  40.635630 -74.098051
# 257  Staten Island               Howland Hook  40.638433 -74.186223
# 258  Staten Island                   Elm Park  40.630147 -74.141817
# 259       Brooklyn             Remsen Village  40.652117 -73.916653
# 260       Brooklyn                   New Lots  40.662744 -73.885118
# 261       Brooklyn            Paerdegat Basin  40.631318 -73.902335
# 262       Brooklyn                 Mill Basin  40.615974 -73.915154
# 263         Queens              Jamaica Hills  40.711460 -73.796465
# 264         Queens                     Utopia  40.733500 -73.796717
# 265         Queens                    Pomonok  40.734936 -73.804861
# 266         Queens            Astoria Heights  40.770317 -73.894680
# 267          Bronx          Claremont Village  40.831428 -73.901199
# 268          Bronx          Concourse Village  40.824780 -73.915847
# 269          Bronx                 Mount Eden  40.843826 -73.916556
# 270          Bronx                 Mount Hope  40.848842 -73.908299
# 271      Manhattan               Sutton Place  40.760280 -73.963556
# 272         Queens              Hunters Point  40.743414 -73.953868
# 273      Manhattan                 Turtle Bay  40.752042 -73.967708
# 274      Manhattan                 Tudor City  40.746917 -73.971219
# 275      Manhattan            Stuyvesant Town  40.731000 -73.974052
# 276      Manhattan                   Flatiron  40.739673 -73.990947
# 277         Queens          Sunnyside Gardens  40.745652 -73.918193
# 278         Queens                 Blissville  40.737251 -73.932442
# 279       Brooklyn               Fulton Ferry  40.703281 -73.995508
# 280       Brooklyn               Vinegar Hill  40.703321 -73.981116
# 281       Brooklyn                 Weeksville  40.675040 -73.930531
# 282       Brooklyn          Broadway Junction  40.677861 -73.903317
# 283       Brooklyn                      Dumbo  40.703176 -73.988753
# 284  Staten Island              Manor Heights  40.601810 -74.120594
# 285  Staten Island                Willowbrook  40.603707 -74.132084
# 286  Staten Island               Sandy Ground  40.541140 -74.217766
# 287  Staten Island                Egbertville  40.579119 -74.127272
# 288         Queens                    Roxbury  40.567376 -73.892138
# 289       Brooklyn                  Homecrest  40.598525 -73.959185
# 290         Queens             Middle Village  40.716415 -73.881143
# 291  Staten Island               Prince's Bay  40.526264 -74.201526
# 292  Staten Island            Lighthouse Hill  40.576506 -74.137927
# 293  Staten Island            Richmond Valley  40.519541 -74.229571
# 294         Queens                      Malba  40.790602 -73.826678
# 295       Brooklyn              Highland Park  40.681999 -73.890346
# 296       Brooklyn                    Madison  40.609378 -73.948415
# 297          Bronx                  Bronxdale  40.852723 -73.861726
# 298          Bronx                   Allerton  40.865788 -73.859319
# 299          Bronx        Kingsbridge Heights  40.870392 -73.901523
# 300       Brooklyn                    Erasmus  40.646926 -73.948177
# 301      Manhattan               Hudson Yards  40.756658 -74.000111
# 302         Queens                    Hammels  40.587338 -73.805530
# 303         Queens                  Bayswater  40.611322 -73.765968
# 304         Queens               Queensbridge  40.756091 -73.945631
# 305  Staten Island                  Fox Hills  40.617311 -74.081740

# %%
# Getting latitude and longitude values of New York City.
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geo coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geo coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'QPRKJVEPJENVK2RD4NL3UU5OC4KJ1YJ5GFDPVP1QZSD0JS4Y' 
CLIENT_SECRET = 'TSW1231SYS2PRTJNV2RAURWKGJJC1K4H0T2N0X543JATSMRC'
VERSION = '20180605'

# %%
categoryId = '4bf58dd8d48988d1ca941735'
LIMIT = 100

boroughs = ["Bronx","Manhattan","Brooklyn","Queens","Staten Island"]
Data = {}
for borough in boroughs:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        borough,
        LIMIT,
        categoryId) # PIZZA PLACE CATEGORY ID
    Data[borough] = requests.get(url).json()

# %%
Data
# Out:
# {'Bronx': {'meta': {'code': 200, 'requestId': '5ec3bc30b1cac0001db4f36a'},
#   'response': {'suggestedFilters': {'header': 'Tap to show:',
#     'filters': [{'name': 'Open now', 'key': 'openNow'},
#      {'name': '$-$$$$', 'key': 'price'}]},
#    'geocode': {'what': '',
#     'where': 'bronx',
#     'center': {'lat': 40.84985, 'lng': -73.86641},
#     'displayString': 'Bronx, NY, United States',
#     'cc': 'US',
#     'geometry': {'bounds': {'ne': {'lat': 40.917577, 'lng': -73.74806},
#       'sw': {'lat': 40.785743, 'lng': -73.933808}}},
#     'slug': 'bronx-new-york',
#     'longId': '72057594043038202'},
#    'headerLocation': 'Bronx',
#    'headerFullLocation': 'Bronx',
#    'headerLocationGranularity': 'city',
#    'query': 'pizza',
#    'totalResults': 161,
#    'suggestedBounds': {'ne': {'lat': 40.91530088164544,
#      'lng': -73.77913119443664},
#     'sw': {'lat': 40.80210681515975, 'lng': -73.93441222883635}},
#    'groups': [{'type': 'Recommended Places',
#      'name': 'recommended',
#      'items': [{'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '58935fd798f8aa7c14662653',
#         'name': 'Kingsbridge Social Club',
#         'location': {'address': '3625 Kingsbridge Ave',
#          'lat': 40.88454548045115,
#          'lng': -73.90196378126393,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.88454548045115,
#            'lng': -73.90196378126393},
#           {'label': 'entrance', 'lat': 40.884542, 'lng': -73.901935}],
#          'postalCode': '10463',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3625 Kingsbridge Ave',
#           'Bronx, NY 10463',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '390862740'}},
#        'referralId': 'e-0-58935fd798f8aa7c14662653-0'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b47ee2ff964a520544426e3',
#         'name': "Louie & Ernie's Pizza",
#         'location': {'address': '1300 Crosby Ave',
#          'crossStreet': 'at Waterbury Ave',
#          'lat': 40.83831033779174,
#          'lng': -73.82878549938773,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.83831033779174,
#            'lng': -73.82878549938773},
#           {'label': 'entrance', 'lat': 40.838236, 'lng': -73.828676}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1300 Crosby Ave (at Waterbury Ave)',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b47ee2ff964a520544426e3-1'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4aabd3e6f964a5204a5a20e3',
#         'name': 'Zero Otto Nove',
#         'location': {'address': '2357 Arthur Ave',
#          'crossStreet': 'at E 186th St',
#          'lat': 40.85471353015844,
#          'lng': -73.88838751470229,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.85471353015844,
#            'lng': -73.88838751470229}],
#          'postalCode': '10458',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2357 Arthur Ave (at E 186th St)',
#           'Bronx, NY 10458',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4aabd3e6f964a5204a5a20e3-2'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bb114c4f964a520b9783ce3',
#         'name': "Sam's Pizza",
#         'location': {'address': '232 W 231st St',
#          'crossStreet': 'Godwin Terrace',
#          'lat': 40.87943501792795,
#          'lng': -73.90585879861192,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.87943501792795,
#            'lng': -73.90585879861192},
#           {'label': 'entrance', 'lat': 40.879412, 'lng': -73.906056}],
#          'postalCode': '10463',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['232 W 231st St (Godwin Terrace)',
#           'Bronx, NY 10463',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bb114c4f964a520b9783ce3-3'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4aee1220f964a520ced121e3',
#         'name': 'Full Moon Pizzeria',
#         'location': {'address': '600 E 187th St',
#          'crossStreet': 'at Arthur Ave.',
#          'lat': 40.855505712207126,
#          'lng': -73.88755698445503,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.855505712207126,
#            'lng': -73.88755698445503},
#           {'label': 'entrance', 'lat': 40.855391, 'lng': -73.887518}],
#          'postalCode': '10458',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['600 E 187th St (at Arthur Ave.)',
#           'Bronx, NY 10458',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1963830',
#          'url': 'https://www.seamless.com/menu/full-moon-pizzeria-600-e-187th-st-bronx/1963830?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1963830',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4aee1220f964a520ced121e3-4'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bba4eeeb35776b0edc4ca01',
#         'name': 'Nicks Pizza',
#         'location': {'address': '1356 E Gun Hill Rd',
#          'lat': 40.870351831445014,
#          'lng': -73.84617111612273,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.870351831445014,
#            'lng': -73.84617111612273},
#           {'label': 'entrance', 'lat': 40.870321, 'lng': -73.846286}],
#          'postalCode': '10469',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1356 E Gun Hill Rd',
#           'Bronx, NY 10469',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bba4eeeb35776b0edc4ca01-5'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bc78c0d0050b71372e8b83b',
#         'name': "John & Joe's Pizzeria",
#         'location': {'address': '749 Lydig Ave',
#          'crossStreet': 'at Holland Ave',
#          'lat': 40.854519600273534,
#          'lng': -73.86582375035509,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.854519600273534,
#            'lng': -73.86582375035509},
#           {'label': 'entrance', 'lat': 40.854544, 'lng': -73.86592}],
#          'postalCode': '10462',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['749 Lydig Ave (at Holland Ave)',
#           'Bronx, NY 10462',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '97644157'}},
#        'referralId': 'e-0-4bc78c0d0050b71372e8b83b-6'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b23f2a0f964a520855d24e3',
#         'name': 'Yankee Pizza',
#         'location': {'address': '1616 Westchester Ave',
#          'crossStreet': 'Stratford Avenue',
#          'lat': 40.82935597173562,
#          'lng': -73.87562527910156,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.82935597173562,
#            'lng': -73.87562527910156},
#           {'label': 'entrance', 'lat': 40.829265, 'lng': -73.874881}],
#          'postalCode': '10472',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1616 Westchester Ave (Stratford Avenue)',
#           'Bronx, NY 10472',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b23f2a0f964a520855d24e3-7'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c632f1cde1b2d7fed31e470',
#         'name': "Mario's Pizza",
#         'location': {'address': '3824 Dyre Ave',
#          'crossStreet': 'East 233 Street',
#          'lat': 40.88862762439113,
#          'lng': -73.83126012557018,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.88862762439113,
#            'lng': -73.83126012557018},
#           {'label': 'entrance', 'lat': 40.888648, 'lng': -73.831146}],
#          'postalCode': '10466',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3824 Dyre Ave (East 233 Street)',
#           'Bronx, NY 10466',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c632f1cde1b2d7fed31e470-8'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4ba50da6f964a52046d638e3',
#         'name': 'Katonah Pizza and Pasta',
#         'location': {'address': '4307 Katonah Ave',
#          'lat': 40.89878411126604,
#          'lng': -73.86745706580207,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.89878411126604,
#            'lng': -73.86745706580207},
#           {'label': 'entrance', 'lat': 40.898759, 'lng': -73.867558}],
#          'postalCode': '10470',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['4307 Katonah Ave',
#           'Bronx, NY 10470',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '245923',
#          'url': 'https://www.seamless.com/menu/katonah-pizza--pasta-4307-katonah-ave-bronx/245923?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=245923',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4ba50da6f964a52046d638e3-9'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b2035e6f964a520bc2e24e3',
#         'name': "Emilio's Pizza",
#         'location': {'address': '1051 Morris Park Ave',
#          'crossStreet': 'at Hone Ave.',
#          'lat': 40.848934633803005,
#          'lng': -73.85457970598979,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.848934633803005,
#            'lng': -73.85457970598979},
#           {'label': 'entrance', 'lat': 40.848993, 'lng': -73.854627}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1051 Morris Park Ave (at Hone Ave.)',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b2035e6f964a520bc2e24e3-10'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bca37c5cc8cd13a1f42bdcf',
#         'name': 'Franks Pizza',
#         'location': {'address': '2823 Middletown Rd',
#          'lat': 40.84354988394633,
#          'lng': -73.83600630032399,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.84354988394633,
#            'lng': -73.83600630032399},
#           {'label': 'entrance', 'lat': 40.843577, 'lng': -73.835948}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2823 Middletown Rd',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1626',
#          'url': 'https://www.seamless.com/menu/franks-pizza--restaurant-2823-middletown-rd-bronx/1626?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1626',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bca37c5cc8cd13a1f42bdcf-11'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c7af4b0a8683704ba64154d',
#         'name': 'Franks Original Pizza Italia',
#         'location': {'address': '768 Castle Hill Ave',
#          'lat': 40.82286427195636,
#          'lng': -73.84890931755929,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.82286427195636,
#            'lng': -73.84890931755929},
#           {'label': 'entrance', 'lat': 40.822782, 'lng': -73.848678}],
#          'postalCode': '10473',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['768 Castle Hill Ave',
#           'Bronx, NY 10473',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c7af4b0a8683704ba64154d-12'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b2a6ba8f964a520d9a824e3',
#         'name': 'Pugsley Pizza',
#         'location': {'address': '590 E 191st St',
#          'lat': 40.8588177574385,
#          'lng': -73.88480770171738,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.8588177574385,
#            'lng': -73.88480770171738},
#           {'label': 'entrance', 'lat': 40.858806, 'lng': -73.884834}],
#          'postalCode': '10458',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['590 E 191st St',
#           'Bronx, NY 10458',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b2a6ba8f964a520d9a824e3-13'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b10591af964a5205f6e23e3',
#         'name': "Patricia's",
#         'location': {'address': '1082 Morris Park Ave',
#          'lat': 40.84931298339339,
#          'lng': -73.85353576737785,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.84931298339339,
#            'lng': -73.85353576737785},
#           {'label': 'entrance', 'lat': 40.849229, 'lng': -73.853395}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1082 Morris Park Ave',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '410402136'}},
#        'referralId': 'e-0-4b10591af964a5205f6e23e3-14'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bc39aae4cdfc9b67c999721',
#         'name': "The Original Emilio's Pizza",
#         'location': {'address': '3843 E Tremont Ave',
#          'crossStreet': 'Schley Ave.',
#          'lat': 40.82418781438608,
#          'lng': -73.82018783535575,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.82418781438608,
#            'lng': -73.82018783535575}],
#          'postalCode': '10465',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3843 E Tremont Ave (Schley Ave.)',
#           'Bronx, NY 10465',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bc39aae4cdfc9b67c999721-15'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b4b9bc1f964a520cea126e3',
#         'name': "Loretta's Pizza",
#         'location': {'address': '3276 Layton Ave',
#          'crossStreet': '@ Dean Ave',
#          'lat': 40.83574891392131,
#          'lng': -73.81799692759685,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.83574891392131,
#            'lng': -73.81799692759685},
#           {'label': 'entrance', 'lat': 40.835707, 'lng': -73.817949}],
#          'postalCode': '10465',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3276 Layton Ave (@ Dean Ave)',
#           'Bronx, NY 10465',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '286037',
#          'url': 'https://www.seamless.com/menu/lorettas-pizza-3276-layton-ave-bronx/286037?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=286037',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b4b9bc1f964a520cea126e3-16'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4cbf2e697dc9a0930f5e37f5',
#         'name': "Domenick's Pizzeria",
#         'location': {'address': '1015 Allerton Ave',
#          'crossStreet': 'Hone Ave.',
#          'lat': 40.86557632085589,
#          'lng': -73.85812427249664,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.86557632085589,
#            'lng': -73.85812427249664},
#           {'label': 'entrance', 'lat': 40.865622, 'lng': -73.858091}],
#          'postalCode': '10469',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1015 Allerton Ave (Hone Ave.)',
#           'Bronx, NY 10469',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '349602303'}},
#        'referralId': 'e-0-4cbf2e697dc9a0930f5e37f5-17'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b86e7d7f964a5201ea531e3',
#         'name': 'Sorrento Pizzeria',
#         'location': {'address': '2004 Williamsbridge Rd',
#          'crossStreet': 'at Neill ave',
#          'lat': 40.85438866680259,
#          'lng': -73.85451988387852,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.85438866680259,
#            'lng': -73.85451988387852},
#           {'label': 'entrance', 'lat': 40.854451, 'lng': -73.854397}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2004 Williamsbridge Rd (at Neill ave)',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '61482',
#          'url': 'https://www.seamless.com/menu/sorrentos-pizza-2004-williamsbridge-rd-bronx/61482?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=61482',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b86e7d7f964a5201ea531e3-18'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b67925df964a520ba552be3',
#         'name': "Captain's Pizza",
#         'location': {'address': '1056 Morris Park Ave',
#          'lat': 40.84887580417101,
#          'lng': -73.85437462135108,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.84887580417101,
#            'lng': -73.85437462135108}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1056 Morris Park Ave',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '1465865',
#          'url': 'https://www.seamless.com/menu/captains-pizza-1056-morris-park-ave-the-bronx/1465865?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1465865',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b67925df964a520ba552be3-19'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bad3ad4f964a520cc3b3be3',
#         'name': 'Crosby Pizza',
#         'location': {'address': '1731 Crosby Ave',
#          'crossStreet': 'Roberts',
#          'lat': 40.84614,
#          'lng': -73.83197,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.84614,
#            'lng': -73.83197},
#           {'label': 'entrance', 'lat': 40.846123, 'lng': -73.831823}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1731 Crosby Ave (Roberts)',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '302523',
#          'url': 'https://www.seamless.com/menu/crosbys-pizza-1731-crosby-ave-bronx/302523?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=302523',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []},
#         'venuePage': {'id': '413684916'}},
#        'referralId': 'e-0-4bad3ad4f964a520cc3b3be3-20'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4e4cf8c3bd413c4cc66da683',
#         'name': "Captain's Pizzeria & Restaurant",
#         'location': {'address': '1056 Morris Park Ave',
#          'lat': 40.848876976000696,
#          'lng': -73.85437663865966,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.848876976000696,
#            'lng': -73.85437663865966},
#           {'label': 'entrance', 'lat': 40.848823, 'lng': -73.854285}],
#          'postalCode': '10461',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1056 Morris Park Ave',
#           'Bronx, NY 10461',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4e4cf8c3bd413c4cc66da683-21'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b140a90f964a520489c23e3',
#         'name': "Bellini's Pizza",
#         'location': {'address': '625 E 189th St',
#          'lat': 40.8570710822463,
#          'lng': -73.88535048830875,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.8570710822463,
#            'lng': -73.88535048830875}],
#          'postalCode': '10458',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['625 E 189th St',
#           'Bronx, NY 10458',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b140a90f964a520489c23e3-22'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c59fc675c57c9b67b3b1c4a',
#         'name': "Broadway Joe's Pizza",
#         'location': {'address': '5983 Broadway',
#          'lat': 40.8898981274626,
#          'lng': -73.8985080809925,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.8898981274626,
#            'lng': -73.8985080809925},
#           {'label': 'entrance', 'lat': 40.889922, 'lng': -73.898427}],
#          'postalCode': '10471',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['5983 Broadway',
#           'Bronx, NY 10471',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c59fc675c57c9b67b3b1c4a-23'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b638b04f964a52036822ae3',
#         'name': "Goodfella's Pizza",
#         'location': {'address': '3661 Waldo Ave',
#          'crossStreet': 'at W 238th St.',
#          'lat': 40.88712132107213,
#          'lng': -73.90430120748528,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.88712132107213,
#            'lng': -73.90430120748528},
#           {'label': 'entrance', 'lat': 40.886969, 'lng': -73.904394}],
#          'postalCode': '10463',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3661 Waldo Ave (at W 238th St.)',
#           'Bronx, NY 10463',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '301477',
#          'url': 'https://www.seamless.com/menu/goodfellas-pizza-3661-waldo-ave-bronx/301477?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=301477',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b638b04f964a52036822ae3-24'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b4b9f1df964a5201fa226e3',
#         'name': 'Tosca Café',
#         'location': {'address': '4034 E Tremont Ave',
#          'crossStreet': 'at Miles Ave',
#          'lat': 40.819204436132736,
#          'lng': -73.81746681637895,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.819204436132736,
#            'lng': -73.81746681637895}],
#          'postalCode': '10465',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['4034 E Tremont Ave (at Miles Ave)',
#           'Bronx, NY 10465',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b4b9f1df964a5201fa226e3-25'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b6f0a6cf964a520e0d82ce3',
#         'name': 'Marconi Pizzeria',
#         'location': {'address': '181 E Gun Hill Rd',
#          'crossStreet': 'btw Bainbridge & Wayne',
#          'lat': 40.880766406357665,
#          'lng': -73.87780801932352,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.880766406357665,
#            'lng': -73.87780801932352},
#           {'label': 'entrance', 'lat': 40.880881, 'lng': -73.877738}],
#          'postalCode': '10467',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['181 E Gun Hill Rd (btw Bainbridge & Wayne)',
#           'Bronx, NY 10467',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b6f0a6cf964a520e0d82ce3-26'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4af71916f964a520cf0522e3',
#         'name': "Michaelangelo's Coal Fired Brick Oven Pizza Restaurant",
#         'location': {'address': '2477 Arthur Ave',
#          'lat': 40.85741189614754,
#          'lng': -73.88646821282298,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.85741189614754,
#            'lng': -73.88646821282298},
#           {'label': 'entrance', 'lat': 40.857301, 'lng': -73.886231}],
#          'postalCode': '10458',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2477 Arthur Ave',
#           'Bronx, NY 10458',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d110941735',
#           'name': 'Italian Restaurant',
#           'pluralName': 'Italian Restaurants',
#           'shortName': 'Italian',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '421532',
#          'url': 'https://www.seamless.com/menu/michaelangelos-2477-arthur-ave-bronx/421532?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=421532',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4af71916f964a520cf0522e3-27'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c7fce5e078e3704e7225494',
#         'name': "Napoli's Best Pizza",
#         'location': {'address': '521 E Tremont Ave',
#          'lat': 40.846903000000005,
#          'lng': -73.896335,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.846903000000005,
#            'lng': -73.896335}],
#          'postalCode': '10457',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['521 E Tremont Ave',
#           'Bronx, NY 10457',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c7fce5e078e3704e7225494-28'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c6994e3c946e21eb28eea8e',
#         'name': "Salvatore's of Soho",
#         'location': {'address': '3738 Riverdale Ave',
#          'crossStreet': 'at 238th Street.',
#          'lat': 40.887632762259415,
#          'lng': -73.90717756259086,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.887632762259415,
#            'lng': -73.90717756259086},
#           {'label': 'entrance', 'lat': 40.887634, 'lng': -73.907092}],
#          'postalCode': '10463',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3738 Riverdale Ave (at 238th Street.)',
#           'Bronx, NY 10463',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c6994e3c946e21eb28eea8e-29'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bf865a24a67c928215e25cf',
#         'name': 'Pizza Chef',
#         'location': {'address': '564 W 235th St',
#          'crossStreet': 'btw Johnson & Netherland',
#          'lat': 40.88563972079103,
#          'lng': -73.91024487885741,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.88563972079103,
#            'lng': -73.91024487885741}],
#          'postalCode': '10463',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['564 W 235th St (btw Johnson & Netherland)',
#           'Bronx, NY 10463',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '72553',
#          'url': 'https://www.seamless.com/menu/pizza-chef-564-w-235th-st-riverdale/72553?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=72553',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bf865a24a67c928215e25cf-30'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c78a45597028cfa05b6d8fe',
#         'name': "Tommy's Pizzeria",
#         'location': {'address': '4033 E Tremont Ave',
#          'crossStreet': 'at Gerber Pl',
#          'lat': 40.81957293563141,
#          'lng': -73.81748174041417,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.81957293563141,
#            'lng': -73.81748174041417},
#           {'label': 'entrance', 'lat': 40.819568, 'lng': -73.817341}],
#          'postalCode': '10465',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['4033 E Tremont Ave (at Gerber Pl)',
#           'Bronx, NY 10465',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c78a45597028cfa05b6d8fe-31'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4e4dd9afbd4101d0d79cbd5c',
#         'name': "Cestra's Pizza",
#         'location': {'address': '3617 E Tremont Ave',
#          'lat': 40.828733,
#          'lng': -73.823949,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.828733,
#            'lng': -73.823949},
#           {'label': 'entrance', 'lat': 40.828655, 'lng': -73.824102}],
#          'postalCode': '10465',
#          'cc': 'US',
#          'city': 'Bronx',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3617 E Tremont Ave',
#           'Bronx, NY 10465',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '306574',
#          'url': 'https://www.seamless.com/menu/cestras-pizza-3617-e-tremont-ave-bronx/306574?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=306574',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4e4dd9afbd4101d0d79cbd5c-32'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b4e3e87f964a5209de626e3',
#         'name': "Patricia's of Tremont",
#         'location': {'address': '3883 E Tremont Ave',
#          'crossStreet': 'btwn Schley & Dewey Ave.',
#          'lat': 40.823118889430276,
#          'lng': -73.81940281496017,
#          'labeledLatLngs': [{'label': 'display',
# ...
#          'lat': 40.626047,
#          'lng': -74.137443,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.626047,
#            'lng': -74.137443},
#           {'label': 'entrance', 'lat': 40.626159, 'lng': -74.137234}],
#          'postalCode': '10302',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1499 Forest',
#           'Staten Island, NY 10302',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b6ca45cf964a520d0482ce3-87'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c3a14ab1e06d13a99b17a3e',
#         'name': 'Tomato N Basil II',
#         'location': {'address': '10 New Dorp Ln',
#          'crossStreet': 'at Richmond Rd',
#          'lat': 40.5756330059179,
#          'lng': -74.11961752677746,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.5756330059179,
#            'lng': -74.11961752677746}],
#          'postalCode': '10306',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['10 New Dorp Ln (at Richmond Rd)',
#           'Staten Island, NY 10306',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c3a14ab1e06d13a99b17a3e-88'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b6310d6f964a520ae602ae3',
#         'name': 'Mama Rosaria Pizza',
#         'location': {'address': '2146 Forest Ave',
#          'lat': 40.62648342258495,
#          'lng': -74.16100953770832,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.62648342258495,
#            'lng': -74.16100953770832},
#           {'label': 'entrance', 'lat': 40.626441, 'lng': -74.161013}],
#          'postalCode': '10303',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2146 Forest Ave',
#           'Staten Island, NY 10303',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b6310d6f964a520ae602ae3-89'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4b7b3eedf964a520405a2fe3',
#         'name': 'Planet Wings',
#         'location': {'address': '698 Arthur Kill Rd',
#          'lat': 40.55966485623672,
#          'lng': -74.16457399656316,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.55966485623672,
#            'lng': -74.16457399656316},
#           {'label': 'entrance', 'lat': 40.559547, 'lng': -74.164582}],
#          'postalCode': '10308',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['698 Arthur Kill Rd',
#           'Staten Island, NY 10308',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d14c941735',
#           'name': 'Wings Joint',
#           'pluralName': 'Wings Joints',
#           'shortName': 'Wings',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4b7b3eedf964a520405a2fe3-90'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4bcc87a60687ef3b3961dfcc',
#         'name': "Mr. Pizza's Pasta House",
#         'location': {'address': '2325 Richmond Ave',
#          'crossStreet': 'Heartland Stores',
#          'lat': 40.591355721612494,
#          'lng': -74.16431045024412,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.591355721612494,
#            'lng': -74.16431045024412}],
#          'postalCode': '10314',
#          'cc': 'US',
#          'neighborhood': 'New Springville',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['2325 Richmond Ave (Heartland Stores)',
#           'Staten Island, NY 10314',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4bcc87a60687ef3b3961dfcc-91'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4e4e63e8bd4101d0d7a915e2',
#         'name': 'Famous M&J',
#         'location': {'address': '10 Akron St.',
#          'crossStreet': 'Richmond Ave.',
#          'lat': 40.61182172886354,
#          'lng': -74.15841039064695,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.61182172886354,
#            'lng': -74.15841039064695}],
#          'postalCode': '10314',
#          'cc': 'US',
#          'city': 'New York',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['10 Akron St. (Richmond Ave.)',
#           'New York, NY 10314',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4e4e63e8bd4101d0d7a915e2-92'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4dcdbab1ae603b786d1df416',
#         'name': 'My Family Pizza',
#         'location': {'address': '1032 Castleton Ave',
#          'crossStreet': 'Broadway',
#          'lat': 40.634461,
#          'lng': -74.116905,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.634461,
#            'lng': -74.116905},
#           {'label': 'entrance', 'lat': 40.634517, 'lng': -74.116927}],
#          'postalCode': '10310',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['1032 Castleton Ave (Broadway)',
#           'Staten Island, NY 10310',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4dcdbab1ae603b786d1df416-93'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4f32a18f19836c91c7ea8df6',
#         'name': 'Frank and Maries Place',
#         'location': {'address': '300 Morningstar Rd',
#          'lat': 40.631051,
#          'lng': -74.146958,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.631051,
#            'lng': -74.146958},
#           {'label': 'entrance', 'lat': 40.631061, 'lng': -74.147048}],
#          'postalCode': '10303',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['300 Morningstar Rd',
#           'Staten Island, NY 10303',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4f32a18f19836c91c7ea8df6-94'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '542de48c498ea11026abb433',
#         'name': "Miglino's",
#         'location': {'address': '6833 Amboy Rd',
#          'lat': 40.519267,
#          'lng': -74.22968399999999,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.519267,
#            'lng': -74.22968399999999}],
#          'postalCode': '10309',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['6833 Amboy Rd',
#           'Staten Island, NY 10309',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-542de48c498ea11026abb433-95'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4d56d520fb65236a1bbd0ab4',
#         'name': 'M&J Pizzeria',
#         'location': {'address': '10 Akron St',
#          'crossStreet': 'Richmond Ave.',
#          'lat': 40.61174119,
#          'lng': -74.15840239,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.61174119,
#            'lng': -74.15840239}],
#          'postalCode': '10314',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['10 Akron St (Richmond Ave.)',
#           'Staten Island, NY 10314',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'delivery': {'id': '297445',
#          'url': 'https://www.seamless.com/menu/m--j-carini-pizzeria-10-akron-plz-staten-island/297445?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=297445',
#          'provider': {'name': 'seamless',
#           'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#            'sizes': [40, 50],
#            'name': '/delivery_provider_seamless_20180129.png'}}},
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4d56d520fb65236a1bbd0ab4-96'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '4c75c24466be6dcb8782c10f',
#         'name': "Alessio's Pizza",
#         'location': {'address': '3555 Victory Blvd',
#          'crossStreet': 'Travis Ave & Signs Rd',
#          'lat': 40.60134,
#          'lng': -74.176867,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.60134,
#            'lng': -74.176867}],
#          'postalCode': '10314',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3555 Victory Blvd (Travis Ave & Signs Rd)',
#           'Staten Island, NY 10314',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-4c75c24466be6dcb8782c10f-97'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '563a80d4cd109c046997aaff',
#         'name': 'Ti Amo Pizza',
#         'location': {'address': '3555 Victory Blvd',
#          'lat': 40.601198,
#          'lng': -74.176593,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.601198,
#            'lng': -74.176593}],
#          'postalCode': '10314',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3555 Victory Blvd',
#           'Staten Island, NY 10314',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-563a80d4cd109c046997aaff-98'},
#       {'reasons': {'count': 0,
#         'items': [{'summary': 'This spot is popular',
#           'type': 'general',
#           'reasonName': 'globalInteractionReason'}]},
#        'venue': {'id': '50ba9dc7498e6c9d6012071b',
#         'name': 'Pizza Station',
#         'location': {'address': '3555 Victory Blvd',
#          'lat': 40.6014798496239,
#          'lng': -74.1768841600483,
#          'labeledLatLngs': [{'label': 'display',
#            'lat': 40.6014798496239,
#            'lng': -74.1768841600483}],
#          'postalCode': '10314',
#          'cc': 'US',
#          'city': 'Staten Island',
#          'state': 'NY',
#          'country': 'United States',
#          'formattedAddress': ['3555 Victory Blvd',
#           'Staten Island, NY 10314',
#           'United States']},
#         'categories': [{'id': '4bf58dd8d48988d1ca941735',
#           'name': 'Pizza Place',
#           'pluralName': 'Pizza Places',
#           'shortName': 'Pizza',
#           'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#            'suffix': '.png'},
#           'primary': True}],
#         'photos': {'count': 0, 'groups': []}},
#        'referralId': 'e-0-50ba9dc7498e6c9d6012071b-99'}]}]}}}

# %%
df_venues={}
for borough in boroughs:
    venues = json_normalize(Data[borough]['response']['groups'][0]['items'])
    df_venues[borough] = venues[['venue.name', 'venue.location.address', 'venue.location.lat', 'venue.location.lng']]
    df_venues[borough].columns = ['Name', 'Address', 'Lat', 'Lng']

# %%
maps = {}
for borough in boroughs:
    borough_lat = np.mean([Data[borough]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        Data[borough]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    borough_lng = np.mean([Data[borough]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        Data[borough]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[borough] = folium.Map(location=[borough_lat, borough_lng], zoom_start=11)

    # add markers to map
    for lat, lng, label in zip(df_venues[borough]['Lat'], df_venues[borough]['Lng'], df_venues[borough]['Name']):
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(maps[borough])  
    print(f"Total number of pizza places in {borough} = ", Data[borough]['response']['totalResults'])
# Out:
# Total number of pizza places in Bronx =  161
# Total number of pizza places in Manhattan =  255
# Total number of pizza places in Brooklyn =  232
# Total number of pizza places in Queens =  187
# Total number of pizza places in Staten Island =  142

# %% [markdown]
# Above data shows the number of Pizza places in different borough.
